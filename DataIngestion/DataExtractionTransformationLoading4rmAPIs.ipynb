# %% [markdown]
# Data Extraction Using the Github API
#
# Script includes extracting data from an API, preprocessing it and storing it in a DuckDB database for analytics

# %%
#Sending a get request

import requests
url = "https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/events"
response = requests.get(url)
data = response.json()
print(data)
# Out:
# [{'id': '49063897817', 'type': 'WatchEvent', 'actor': {'id': 73944641, 'login': 'yousamaa', 'display_login': 'yousamaa', 'gravatar_id': '', 'url': 'https://api.github.com/users/yousamaa', 'avatar_url': 'https://avatars.githubusercontent.com/u/73944641?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-25T13:02:02Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '49055464165', 'type': 'WatchEvent', 'actor': {'id': 5618377, 'login': 'phiskus', 'display_login': 'phiskus', 'gravatar_id': '', 'url': 'https://api.github.com/users/phiskus', 'avatar_url': 'https://avatars.githubusercontent.com/u/5618377?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-25T09:09:23Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '49051922419', 'type': 'ForkEvent', 'actor': {'id': 139359113, 'login': 'krishna-prasath-hat', 'display_login': 'krishna-prasath-hat', 'gravatar_id': '', 'url': 'https://api.github.com/users/krishna-prasath-hat', 'avatar_url': 'https://avatars.githubusercontent.com/u/139359113?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'forkee': {'id': 972506434, 'node_id': 'R_kgDOOfdFQg', 'name': 'data-engineering-zoomcamp', 'full_name': 'krishna-prasath-hat/data-engineering-zoomcamp', 'private': False, 'owner': {'login': 'krishna-prasath-hat', 'id': 139359113, 'node_id': 'U_kgDOCE5ziQ', 'avatar_url': 'https://avatars.githubusercontent.com/u/139359113?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/krishna-prasath-hat', 'html_url': 'https://github.com/krishna-prasath-hat', 'followers_url': 'https://api.github.com/users/krishna-prasath-hat/followers', 'following_url': 'https://api.github.com/users/krishna-prasath-hat/following{/other_user}', 'gists_url': 'https://api.github.com/users/krishna-prasath-hat/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/krishna-prasath-hat/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/krishna-prasath-hat/subscriptions', 'organizations_url': 'https://api.github.com/users/krishna-prasath-hat/orgs', 'repos_url': 'https://api.github.com/users/krishna-prasath-hat/repos', 'events_url': 'https://api.github.com/users/krishna-prasath-hat/events{/privacy}', 'received_events_url': 'https://api.github.com/users/krishna-prasath-hat/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/krishna-prasath-hat/data-engineering-zoomcamp', 'description': 'Data Engineering Zoomcamp is a free nine-week course that covers the fundamentals of data engineering.', 'fork': True, 'url': 'https://api.github.com/repos/krishna-prasath-hat/data-engineering-zoomcamp', 'forks_url': 'https://api.github.com/repos/krishna-prasath-hat/data-engineering-zoomcamp/forks', 'keys_url': 'https://api.github.com/repos/krishna-prasath-hat/data-engineering-zoomcamp/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/krishna-prasath-hat/data-engineering-zoomcamp/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/krishna-prasath-hat/data-engineering-zoomcamp/teams', 'hooks_url': 'https://api.github.com/repos/krishna-prasath-hat/data-engineering-zoomcamp/hooks', 'issue_events_url': 'https://api.github.com/repos/krishna-prasat ...

# %%
#Streming request example
#import websocket

#def on_message(ws, message):
#    print("Received event:", message)

#ws = websocket.WebSocketApp("wss://api.example.com/stream", on_message=on_message)
#ws.run_forever()

# %%
#checking API rate limits
url = "https://api.github.com/rate_limit"
response = requests.get(url)
response.json()['rate']['remaining']
# Out:
# 60

# %%
#using the rate limit
import time
url = "https://api.github.com/rate_limit"
response = requests.get(url)
remaining = response.json()['rate']['remaining']

if remaining == 0:
    reset_time = response.json()['rate']['reset']
    wait_time = reset_time - time.time()
    time.sleep(wait_time)
    response = requests.get(url)

# %%
#Working with Authentication
import requests
url = "https://api.github.com/user"
response = requests.get(url, auth=('username', 'password'))

#Alternatively
from google.colab import userdata
username = userdata.get('github_username')
password = userdata.get('github_password')
response = requests.get(url, auth=(username, password))

#API Token
API_token = userdata.get('githubtoken')
headers = {
    'Authorization': f'bearer{API_token}'
}
url = "https://api.github.com/user"
response = requests.get(url, headers=headers)

response.json()

# %%
#Pagination
#url = "https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/issues"
url = "https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/events"
response = requests.get(url)
response.headers['Link']
# Out:
# '<https://api.github.com/repositories/419661684/events?page=2>; rel="next", <https://api.github.com/repositories/419661684/events?page=10>; rel="last"'

# %%
response.links['next']['url']
# Out:
# 'https://api.github.com/repositories/419661684/events?page=2'

# %%
url = "https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/events"
while True:
    response = requests.get(url)
    data = response.json()
    print(len(data))
    if 'next' not in response.links:
      break
    url = response.links['next']['url']
    print(url)
# Out:
# 30
# https://api.github.com/repositories/419661684/events?page=2
# 30
# https://api.github.com/repositories/419661684/events?page=3
# 30
# https://api.github.com/repositories/419661684/events?page=4
# 30
# https://api.github.com/repositories/419661684/events?page=5
# 30
# https://api.github.com/repositories/419661684/events?page=6
# 30
# https://api.github.com/repositories/419661684/events?page=7
# 30
# https://api.github.com/repositories/419661684/events?page=8
# 30
# https://api.github.com/repositories/419661684/events?page=9
# 30
# https://api.github.com/repositories/419661684/events?page=10
# 26

# %% [markdown]
# Storage

# %%
def events_getter():
  url = "https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp/events"
  while True:
    response = requests.get(url)
    data = response.json()
    yield data
    if 'next' not in response.links:
      break
    url = response.links['next']['url']

# %%
events_pages = events_getter()

for event_page in events_pages:
  print(event_page)
# Out:
# [{'id': '49063897817', 'type': 'WatchEvent', 'actor': {'id': 73944641, 'login': 'yousamaa', 'display_login': 'yousamaa', 'gravatar_id': '', 'url': 'https://api.github.com/users/yousamaa', 'avatar_url': 'https://avatars.githubusercontent.com/u/73944641?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-25T13:02:02Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '49055464165', 'type': 'WatchEvent', 'actor': {'id': 5618377, 'login': 'phiskus', 'display_login': 'phiskus', 'gravatar_id': '', 'url': 'https://api.github.com/users/phiskus', 'avatar_url': 'https://avatars.githubusercontent.com/u/5618377?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-25T09:09:23Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '49051922419', 'type': 'ForkEvent', 'actor': {'id': 139359113, 'login': 'krishna-prasath-hat', 'display_login': 'krishna-prasath-hat', 'gravatar_id': '', 'url': 'https://api.github.com/users/krishna-prasath-hat', 'avatar_url': 'https://avatars.githubusercontent.com/u/139359113?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'forkee': {'id': 972506434, 'node_id': 'R_kgDOOfdFQg', 'name': 'data-engineering-zoomcamp', 'full_name': 'krishna-prasath-hat/data-engineering-zoomcamp', 'private': False, 'owner': {'login': 'krishna-prasath-hat', 'id': 139359113, 'node_id': 'U_kgDOCE5ziQ', 'avatar_url': 'https://avatars.githubusercontent.com/u/139359113?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/krishna-prasath-hat', 'html_url': 'https://github.com/krishna-prasath-hat', 'followers_url': 'https://api.github.com/users/krishna-prasath-hat/followers', 'following_url': 'https://api.github.com/users/krishna-prasath-hat/following{/other_user}', 'gists_url': 'https://api.github.com/users/krishna-prasath-hat/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/krishna-prasath-hat/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/krishna-prasath-hat/subscriptions', 'organizations_url': 'https://api.github.com/users/krishna-prasath-hat/orgs', 'repos_url': 'https://api.github.com/users/krishna-prasath-hat/repos', 'events_url': 'https://api.github.com/users/krishna-prasath-hat/events{/privacy}', 'received_events_url': 'https://api.github.com/users/krishna-prasath-hat/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/krishna-prasath-hat/data-engineering-zoomcamp', 'description': 'Data Engineering Zoomcamp is a free nine-week course that covers the fundamentals of data engineering.', 'fork': True, 'url': 'https://api.github.com/repos/krishna-prasath-hat/data-engineering-zoomcamp', 'forks_url': 'https://api.github.com/repos/krishna-prasath-hat/data-engineering-zoomcamp/forks', 'keys_url': 'https://api.github.com/repos/krishna-prasath-hat/data-engineering-zoomcamp/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/krishna-prasath-hat/data-engineering-zoomcamp/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/krishna-prasath-hat/data-engineering-zoomcamp/teams', 'hooks_url': 'https://api.github.com/repos/krishna-prasath-hat/data-engineering-zoomcamp/hooks', 'issue_events_url': 'https://api.github.com/repos/krishna-prasat ...
# [{'id': '48952124339', 'type': 'WatchEvent', 'actor': {'id': 208734907, 'login': 'alyprovy', 'display_login': 'alyprovy', 'gravatar_id': '', 'url': 'https://api.github.com/users/alyprovy', 'avatar_url': 'https://avatars.githubusercontent.com/u/208734907?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-23T01:26:41Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '48950216740', 'type': 'WatchEvent', 'actor': {'id': 196280502, 'login': 'RayleighFading', 'display_login': 'RayleighFading', 'gravatar_id': '', 'url': 'https://api.github.com/users/RayleighFading', 'avatar_url': 'https://avatars.githubusercontent.com/u/196280502?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-22T23:39:06Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '48949776868', 'type': 'WatchEvent', 'actor': {'id': 164670722, 'login': 'Start-Learn-build', 'display_login': 'Start-Learn-build', 'gravatar_id': '', 'url': 'https://api.github.com/users/Start-Learn-build', 'avatar_url': 'https://avatars.githubusercontent.com/u/164670722?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-22T23:14:00Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '48949510377', 'type': 'WatchEvent', 'actor': {'id': 151232563, 'login': 'Teja8632', 'display_login': 'Teja8632', 'gravatar_id': '', 'url': 'https://api.github.com/users/Teja8632', 'avatar_url': 'https://avatars.githubusercontent.com/u/151232563?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-22T23:00:16Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '48949405553', 'type': 'ForkEvent', 'actor': {'id': 2171047, 'login': 'biblianthrope', 'display_login': 'biblianthrope', 'gravatar_id': '', 'url': 'https://api.github.com/users/biblianthrope', 'avatar_url': 'https://avatars.githubusercontent.com/u/2171047?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'forkee': {'id': 971029568, 'node_id': 'R_kgDOOeC8QA', 'name': 'data-engineering-zoomcamp', 'full_name': 'biblianthrope/data-engineering-zoomcamp', 'private': False, 'owner': {'login': 'biblianthrope', 'id': 2171047, 'node_id': 'MDQ6VXNlcjIxNzEwNDc=', 'avatar_url': 'https://avatars.githubusercontent.com/u/2171047?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/biblianthrope', 'html_url': 'https://github.com/biblianthrope', 'followers_url': 'https://api.github.com/users/biblianthrope/followers', 'following_url': 'https://api.github.com/users/biblianthrope/following{/other_user}', 'gists_url': 'https://api.github.com/users/biblianthrope/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/biblianthrope/starred{/owner}{ ...
# [{'id': '48899190568', 'type': 'WatchEvent', 'actor': {'id': 89947614, 'login': 'Gejix', 'display_login': 'Gejix', 'gravatar_id': '', 'url': 'https://api.github.com/users/Gejix', 'avatar_url': 'https://avatars.githubusercontent.com/u/89947614?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-21T19:36:26Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '48896350222', 'type': 'WatchEvent', 'actor': {'id': 208511513, 'login': 'gregorysigelbaum', 'display_login': 'gregorysigelbaum', 'gravatar_id': '', 'url': 'https://api.github.com/users/gregorysigelbaum', 'avatar_url': 'https://avatars.githubusercontent.com/u/208511513?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-21T17:58:35Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '48896298080', 'type': 'WatchEvent', 'actor': {'id': 47484699, 'login': 'dataskeptic', 'display_login': 'dataskeptic', 'gravatar_id': '', 'url': 'https://api.github.com/users/dataskeptic', 'avatar_url': 'https://avatars.githubusercontent.com/u/47484699?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-21T17:56:46Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '48895002839', 'type': 'WatchEvent', 'actor': {'id': 117711617, 'login': 'heykvr', 'display_login': 'heykvr', 'gravatar_id': '', 'url': 'https://api.github.com/users/heykvr', 'avatar_url': 'https://avatars.githubusercontent.com/u/117711617?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-21T17:13:23Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '48894763854', 'type': 'WatchEvent', 'actor': {'id': 116665336, 'login': 'mohitthakur9901', 'display_login': 'mohitthakur9901', 'gravatar_id': '', 'url': 'https://api.github.com/users/mohitthakur9901', 'avatar_url': 'https://avatars.githubusercontent.com/u/116665336?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-21T17:05:15Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '48894695648', 'type': 'WatchEvent', 'actor': {'id': 108749886, 'login': 'CoderMANE321', 'display_login': 'CoderMANE321', 'gravatar_id': '', 'url': 'https://api.github.com/users/CoderMANE321', 'avatar_url': 'https://avatars.githubusercontent.com/u/108749886?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-21T17 ...
# [{'id': '48869280221', 'type': 'WatchEvent', 'actor': {'id': 14320144, 'login': 'wangjiahong', 'display_login': 'wangjiahong', 'gravatar_id': '', 'url': 'https://api.github.com/users/wangjiahong', 'avatar_url': 'https://avatars.githubusercontent.com/u/14320144?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-20T21:35:44Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '48868424548', 'type': 'ForkEvent', 'actor': {'id': 34229709, 'login': 'kungsiuchun', 'display_login': 'kungsiuchun', 'gravatar_id': '', 'url': 'https://api.github.com/users/kungsiuchun', 'avatar_url': 'https://avatars.githubusercontent.com/u/34229709?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'forkee': {'id': 969732209, 'node_id': 'R_kgDOOczwcQ', 'name': 'data-engineering-zoomcamp-2025', 'full_name': 'kungsiuchun/data-engineering-zoomcamp-2025', 'private': False, 'owner': {'login': 'kungsiuchun', 'id': 34229709, 'node_id': 'MDQ6VXNlcjM0MjI5NzA5', 'avatar_url': 'https://avatars.githubusercontent.com/u/34229709?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/kungsiuchun', 'html_url': 'https://github.com/kungsiuchun', 'followers_url': 'https://api.github.com/users/kungsiuchun/followers', 'following_url': 'https://api.github.com/users/kungsiuchun/following{/other_user}', 'gists_url': 'https://api.github.com/users/kungsiuchun/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/kungsiuchun/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/kungsiuchun/subscriptions', 'organizations_url': 'https://api.github.com/users/kungsiuchun/orgs', 'repos_url': 'https://api.github.com/users/kungsiuchun/repos', 'events_url': 'https://api.github.com/users/kungsiuchun/events{/privacy}', 'received_events_url': 'https://api.github.com/users/kungsiuchun/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/kungsiuchun/data-engineering-zoomcamp-2025', 'description': 'Data Engineering Zoomcamp is a free nine-week course that covers the fundamentals of data engineering.', 'fork': True, 'url': 'https://api.github.com/repos/kungsiuchun/data-engineering-zoomcamp-2025', 'forks_url': 'https://api.github.com/repos/kungsiuchun/data-engineering-zoomcamp-2025/forks', 'keys_url': 'https://api.github.com/repos/kungsiuchun/data-engineering-zoomcamp-2025/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/kungsiuchun/data-engineering-zoomcamp-2025/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/kungsiuchun/data-engineering-zoomcamp-2025/teams', 'hooks_url': 'https://api.github.com/repos/kungsiuchun/data-engineering-zoomcamp-2025/hooks', 'issue_events_url': 'https://api.github.com/repos/kungsiuchun/data-engineering-zoomcamp-2025/issues/events{/number}', 'events_url': 'https://api.github.com/repos/kungsiuchun/data-engineering-zoomcamp-2025/events', 'assignees_url': 'https://api.github.com/repos/kungsiuchun/data-engineering-zoomcamp-2025/assignees{/user}', 'branches_url': 'https://api.github.com/repos/kungsiuchun/data-engineering-zoomcamp-2025/branches{/branch}', 'tags_url': 'https://api.github.com/repos/kungsiuchun/data-engineering-zoomcamp-2025/tags', 'blobs_url': 'https://api.github.com/repos/kungsiuchun/data-engineering-zoomcamp-2025/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/kungsiuchun/data-engineering-zoomcamp-2025/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/kungsiuchun/data-engineering-zoomcamp-2025/git/refs{/sha}', 'trees_url': 'https://api.github.co ...
# [{'id': '48856885271', 'type': 'WatchEvent', 'actor': {'id': 28379537, 'login': 'mayamaya3d', 'display_login': 'mayamaya3d', 'gravatar_id': '', 'url': 'https://api.github.com/users/mayamaya3d', 'avatar_url': 'https://avatars.githubusercontent.com/u/28379537?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-20T00:48:41Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '48855064483', 'type': 'WatchEvent', 'actor': {'id': 117808094, 'login': 'Selalelo', 'display_login': 'Selalelo', 'gravatar_id': '', 'url': 'https://api.github.com/users/Selalelo', 'avatar_url': 'https://avatars.githubusercontent.com/u/117808094?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-19T21:05:01Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '48854948571', 'type': 'WatchEvent', 'actor': {'id': 59185438, 'login': 'Shu-Shine', 'display_login': 'Shu-Shine', 'gravatar_id': '', 'url': 'https://api.github.com/users/Shu-Shine', 'avatar_url': 'https://avatars.githubusercontent.com/u/59185438?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-19T20:52:00Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '48854844900', 'type': 'WatchEvent', 'actor': {'id': 42420929, 'login': 'barbamx', 'display_login': 'barbamx', 'gravatar_id': '', 'url': 'https://api.github.com/users/barbamx', 'avatar_url': 'https://avatars.githubusercontent.com/u/42420929?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-19T20:40:30Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '48854345407', 'type': 'WatchEvent', 'actor': {'id': 29554918, 'login': 'OBigVee', 'display_login': 'OBigVee', 'gravatar_id': '', 'url': 'https://api.github.com/users/OBigVee', 'avatar_url': 'https://avatars.githubusercontent.com/u/29554918?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-19T19:47:07Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '48854299547', 'type': 'WatchEvent', 'actor': {'id': 57643368, 'login': 'NachoGz', 'display_login': 'NachoGz', 'gravatar_id': '', 'url': 'https://api.github.com/users/NachoGz', 'avatar_url': 'https://avatars.githubusercontent.com/u/57643368?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-19T19:42:16Z', 'org': {'id': 72699292, 'login': 'DataTalksClub ...
# [{'id': '48827933829', 'type': 'WatchEvent', 'actor': {'id': 179589718, 'login': 'olaagidee', 'display_login': 'olaagidee', 'gravatar_id': '', 'url': 'https://api.github.com/users/olaagidee', 'avatar_url': 'https://avatars.githubusercontent.com/u/179589718?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-18T12:30:51Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '48826527819', 'type': 'WatchEvent', 'actor': {'id': 122205379, 'login': 'DazaiOsamu666', 'display_login': 'DazaiOsamu666', 'gravatar_id': '', 'url': 'https://api.github.com/users/DazaiOsamu666', 'avatar_url': 'https://avatars.githubusercontent.com/u/122205379?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-18T11:27:28Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '48826236977', 'type': 'WatchEvent', 'actor': {'id': 129497779, 'login': 'Hritikrai55', 'display_login': 'Hritikrai55', 'gravatar_id': '', 'url': 'https://api.github.com/users/Hritikrai55', 'avatar_url': 'https://avatars.githubusercontent.com/u/129497779?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-18T11:13:28Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '48821011464', 'type': 'WatchEvent', 'actor': {'id': 129275484, 'login': 'Varuni29', 'display_login': 'Varuni29', 'gravatar_id': '', 'url': 'https://api.github.com/users/Varuni29', 'avatar_url': 'https://avatars.githubusercontent.com/u/129275484?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-18T07:37:18Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '48819861458', 'type': 'WatchEvent', 'actor': {'id': 7933181, 'login': 'CarlosML27', 'display_login': 'CarlosML27', 'gravatar_id': '', 'url': 'https://api.github.com/users/CarlosML27', 'avatar_url': 'https://avatars.githubusercontent.com/u/7933181?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-18T06:48:49Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '48818615838', 'type': 'WatchEvent', 'actor': {'id': 24859914, 'login': 'gakkispy', 'display_login': 'gakkispy', 'gravatar_id': '', 'url': 'https://api.github.com/users/gakkispy', 'avatar_url': 'https://avatars.githubusercontent.com/u/24859914?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-18T05:47:42Z', 'org': {'i ...
# [{'id': '48765514384', 'type': 'ForkEvent', 'actor': {'id': 95517458, 'login': 'nesibegul', 'display_login': 'nesibegul', 'gravatar_id': '', 'url': 'https://api.github.com/users/nesibegul', 'avatar_url': 'https://avatars.githubusercontent.com/u/95517458?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'forkee': {'id': 967663121, 'node_id': 'R_kgDOOa1eEQ', 'name': 'data-engineering-zoomcamp', 'full_name': 'nesibegul/data-engineering-zoomcamp', 'private': False, 'owner': {'login': 'nesibegul', 'id': 95517458, 'node_id': 'U_kgDOBbF7Eg', 'avatar_url': 'https://avatars.githubusercontent.com/u/95517458?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/nesibegul', 'html_url': 'https://github.com/nesibegul', 'followers_url': 'https://api.github.com/users/nesibegul/followers', 'following_url': 'https://api.github.com/users/nesibegul/following{/other_user}', 'gists_url': 'https://api.github.com/users/nesibegul/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/nesibegul/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/nesibegul/subscriptions', 'organizations_url': 'https://api.github.com/users/nesibegul/orgs', 'repos_url': 'https://api.github.com/users/nesibegul/repos', 'events_url': 'https://api.github.com/users/nesibegul/events{/privacy}', 'received_events_url': 'https://api.github.com/users/nesibegul/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/nesibegul/data-engineering-zoomcamp', 'description': 'Data Engineering Zoomcamp is a free nine-week course that covers the fundamentals of data engineering.', 'fork': True, 'url': 'https://api.github.com/repos/nesibegul/data-engineering-zoomcamp', 'forks_url': 'https://api.github.com/repos/nesibegul/data-engineering-zoomcamp/forks', 'keys_url': 'https://api.github.com/repos/nesibegul/data-engineering-zoomcamp/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/nesibegul/data-engineering-zoomcamp/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/nesibegul/data-engineering-zoomcamp/teams', 'hooks_url': 'https://api.github.com/repos/nesibegul/data-engineering-zoomcamp/hooks', 'issue_events_url': 'https://api.github.com/repos/nesibegul/data-engineering-zoomcamp/issues/events{/number}', 'events_url': 'https://api.github.com/repos/nesibegul/data-engineering-zoomcamp/events', 'assignees_url': 'https://api.github.com/repos/nesibegul/data-engineering-zoomcamp/assignees{/user}', 'branches_url': 'https://api.github.com/repos/nesibegul/data-engineering-zoomcamp/branches{/branch}', 'tags_url': 'https://api.github.com/repos/nesibegul/data-engineering-zoomcamp/tags', 'blobs_url': 'https://api.github.com/repos/nesibegul/data-engineering-zoomcamp/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/nesibegul/data-engineering-zoomcamp/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/nesibegul/data-engineering-zoomcamp/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/nesibegul/data-engineering-zoomcamp/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/nesibegul/data-engineering-zoomcamp/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/nesibegul/data-engineering-zoomcamp/languages', 'stargazers_url': 'https://api.github.com/repos/nesibegul/data-engineering-zoomcamp/stargazers', 'contributors_url': 'https://api.github.com/repos/nesibegul/data-engineering-zoomcamp/contributors', 'subscribers_url': 'https://api.github.com/repos/nesibegul/data-engineering-zoomcamp/subscribers', 'subscription_url': 'https://api.github.com/repos/nesibegul/data-engineering-zoomcamp/subscription', 'commits_url': 'https://api.github.com/repos/nesibegul/data-engineering-zoomcamp/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/nesibegul/data-engineering-zoomcamp/git/commits{/sha}' ...
# [{'id': '48703592309', 'type': 'WatchEvent', 'actor': {'id': 75369752, 'login': 'Mosdef00', 'display_login': 'Mosdef00', 'gravatar_id': '', 'url': 'https://api.github.com/users/Mosdef00', 'avatar_url': 'https://avatars.githubusercontent.com/u/75369752?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-15T13:04:26Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '48699532329', 'type': 'ForkEvent', 'actor': {'id': 88106635, 'login': 'VMynenko', 'display_login': 'VMynenko', 'gravatar_id': '', 'url': 'https://api.github.com/users/VMynenko', 'avatar_url': 'https://avatars.githubusercontent.com/u/88106635?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'forkee': {'id': 966734849, 'node_id': 'R_kgDOOZ80AQ', 'name': 'data-engineering-zoomcamp', 'full_name': 'VMynenko/data-engineering-zoomcamp', 'private': False, 'owner': {'login': 'VMynenko', 'id': 88106635, 'node_id': 'MDQ6VXNlcjg4MTA2NjM1', 'avatar_url': 'https://avatars.githubusercontent.com/u/88106635?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/VMynenko', 'html_url': 'https://github.com/VMynenko', 'followers_url': 'https://api.github.com/users/VMynenko/followers', 'following_url': 'https://api.github.com/users/VMynenko/following{/other_user}', 'gists_url': 'https://api.github.com/users/VMynenko/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/VMynenko/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/VMynenko/subscriptions', 'organizations_url': 'https://api.github.com/users/VMynenko/orgs', 'repos_url': 'https://api.github.com/users/VMynenko/repos', 'events_url': 'https://api.github.com/users/VMynenko/events{/privacy}', 'received_events_url': 'https://api.github.com/users/VMynenko/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/VMynenko/data-engineering-zoomcamp', 'description': 'Data Engineering Zoomcamp is a free nine-week course that covers the fundamentals of data engineering.', 'fork': True, 'url': 'https://api.github.com/repos/VMynenko/data-engineering-zoomcamp', 'forks_url': 'https://api.github.com/repos/VMynenko/data-engineering-zoomcamp/forks', 'keys_url': 'https://api.github.com/repos/VMynenko/data-engineering-zoomcamp/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/VMynenko/data-engineering-zoomcamp/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/VMynenko/data-engineering-zoomcamp/teams', 'hooks_url': 'https://api.github.com/repos/VMynenko/data-engineering-zoomcamp/hooks', 'issue_events_url': 'https://api.github.com/repos/VMynenko/data-engineering-zoomcamp/issues/events{/number}', 'events_url': 'https://api.github.com/repos/VMynenko/data-engineering-zoomcamp/events', 'assignees_url': 'https://api.github.com/repos/VMynenko/data-engineering-zoomcamp/assignees{/user}', 'branches_url': 'https://api.github.com/repos/VMynenko/data-engineering-zoomcamp/branches{/branch}', 'tags_url': 'https://api.github.com/repos/VMynenko/data-engineering-zoomcamp/tags', 'blobs_url': 'https://api.github.com/repos/VMynenko/data-engineering-zoomcamp/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/VMynenko/data-engineering-zoomcamp/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/VMynenko/data-engineering-zoomcamp/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/VMynenko/data-engineering-zoomcamp/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/VMynenko/data-engineering-zoomcamp/statuses/{sha}', 'languages_url': 'https://ap ...
# [{'id': '48640663567', 'type': 'WatchEvent', 'actor': {'id': 67982568, 'login': 'poojakedia', 'display_login': 'poojakedia', 'gravatar_id': '', 'url': 'https://api.github.com/users/poojakedia', 'avatar_url': 'https://avatars.githubusercontent.com/u/67982568?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-14T05:44:01Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '48640041539', 'type': 'WatchEvent', 'actor': {'id': 120700998, 'login': 'betopark97', 'display_login': 'betopark97', 'gravatar_id': '', 'url': 'https://api.github.com/users/betopark97', 'avatar_url': 'https://avatars.githubusercontent.com/u/120700998?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-14T05:16:26Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '48639791213', 'type': 'WatchEvent', 'actor': {'id': 72152218, 'login': 'Bcpeh', 'display_login': 'Bcpeh', 'gravatar_id': '', 'url': 'https://api.github.com/users/Bcpeh', 'avatar_url': 'https://avatars.githubusercontent.com/u/72152218?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-04-14T05:04:10Z', 'org': {'id': 72699292, 'login': 'DataTalksClub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/DataTalksClub', 'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}, {'id': '48639783531', 'type': 'ForkEvent', 'actor': {'id': 72152218, 'login': 'Bcpeh', 'display_login': 'Bcpeh', 'gravatar_id': '', 'url': 'https://api.github.com/users/Bcpeh', 'avatar_url': 'https://avatars.githubusercontent.com/u/72152218?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'forkee': {'id': 965900425, 'node_id': 'R_kgDOOZJ4iQ', 'name': 'data-engineering-zoomcamp', 'full_name': 'Bcpeh/data-engineering-zoomcamp', 'private': False, 'owner': {'login': 'Bcpeh', 'id': 72152218, 'node_id': 'MDQ6VXNlcjcyMTUyMjE4', 'avatar_url': 'https://avatars.githubusercontent.com/u/72152218?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/Bcpeh', 'html_url': 'https://github.com/Bcpeh', 'followers_url': 'https://api.github.com/users/Bcpeh/followers', 'following_url': 'https://api.github.com/users/Bcpeh/following{/other_user}', 'gists_url': 'https://api.github.com/users/Bcpeh/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/Bcpeh/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/Bcpeh/subscriptions', 'organizations_url': 'https://api.github.com/users/Bcpeh/orgs', 'repos_url': 'https://api.github.com/users/Bcpeh/repos', 'events_url': 'https://api.github.com/users/Bcpeh/events{/privacy}', 'received_events_url': 'https://api.github.com/users/Bcpeh/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/Bcpeh/data-engineering-zoomcamp', 'description': 'Data Engineering Zoomcamp is a free nine-week course that covers the fundamentals of data engineering.', 'fork': True, 'url': 'https://api.github.com/repos/Bcpeh/data-engineering-zoomcamp', 'forks_url': 'https://api.github.com/repos/Bcpeh/data-engineering-zoomcamp/forks', 'keys_url': 'https://api.github.com/repos/Bcpeh/data ...
# [{'id': '48618902835', 'type': 'ForkEvent', 'actor': {'id': 14951461, 'login': 'wojsamjan', 'display_login': 'wojsamjan', 'gravatar_id': '', 'url': 'https://api.github.com/users/wojsamjan', 'avatar_url': 'https://avatars.githubusercontent.com/u/14951461?'}, 'repo': {'id': 419661684, 'name': 'DataTalksClub/data-engineering-zoomcamp', 'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'}, 'payload': {'forkee': {'id': 965303562, 'node_id': 'R_kgDOOYldCg', 'name': 'data-engineering-zoomcamp', 'full_name': 'wojsamjan/data-engineering-zoomcamp', 'private': False, 'owner': {'login': 'wojsamjan', 'id': 14951461, 'node_id': 'MDQ6VXNlcjE0OTUxNDYx', 'avatar_url': 'https://avatars.githubusercontent.com/u/14951461?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/wojsamjan', 'html_url': 'https://github.com/wojsamjan', 'followers_url': 'https://api.github.com/users/wojsamjan/followers', 'following_url': 'https://api.github.com/users/wojsamjan/following{/other_user}', 'gists_url': 'https://api.github.com/users/wojsamjan/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/wojsamjan/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/wojsamjan/subscriptions', 'organizations_url': 'https://api.github.com/users/wojsamjan/orgs', 'repos_url': 'https://api.github.com/users/wojsamjan/repos', 'events_url': 'https://api.github.com/users/wojsamjan/events{/privacy}', 'received_events_url': 'https://api.github.com/users/wojsamjan/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/wojsamjan/data-engineering-zoomcamp', 'description': 'Data Engineering Zoomcamp is a free nine-week course that covers the fundamentals of data engineering.', 'fork': True, 'url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp', 'forks_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/forks', 'keys_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/teams', 'hooks_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/hooks', 'issue_events_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/issues/events{/number}', 'events_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/events', 'assignees_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/assignees{/user}', 'branches_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/branches{/branch}', 'tags_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/tags', 'blobs_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/languages', 'stargazers_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/stargazers', 'contributors_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/contributors', 'subscribers_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/subscribers', 'subscription_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/subscription', 'commits_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/git/commit ...

# %%
event = event_page[0]
event
# Out:
# {'id': '48618902835',
#  'type': 'ForkEvent',
#  'actor': {'id': 14951461,
#   'login': 'wojsamjan',
#   'display_login': 'wojsamjan',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/wojsamjan',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/14951461?'},
#  'repo': {'id': 419661684,
#   'name': 'DataTalksClub/data-engineering-zoomcamp',
#   'url': 'https://api.github.com/repos/DataTalksClub/data-engineering-zoomcamp'},
#  'payload': {'forkee': {'id': 965303562,
#    'node_id': 'R_kgDOOYldCg',
#    'name': 'data-engineering-zoomcamp',
#    'full_name': 'wojsamjan/data-engineering-zoomcamp',
#    'private': False,
#    'owner': {'login': 'wojsamjan',
#     'id': 14951461,
#     'node_id': 'MDQ6VXNlcjE0OTUxNDYx',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/14951461?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/wojsamjan',
#     'html_url': 'https://github.com/wojsamjan',
#     'followers_url': 'https://api.github.com/users/wojsamjan/followers',
#     'following_url': 'https://api.github.com/users/wojsamjan/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/wojsamjan/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/wojsamjan/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/wojsamjan/subscriptions',
#     'organizations_url': 'https://api.github.com/users/wojsamjan/orgs',
#     'repos_url': 'https://api.github.com/users/wojsamjan/repos',
#     'events_url': 'https://api.github.com/users/wojsamjan/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/wojsamjan/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/wojsamjan/data-engineering-zoomcamp',
#    'description': 'Data Engineering Zoomcamp is a free nine-week course that covers the fundamentals of data engineering.',
#    'fork': True,
#    'url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp',
#    'forks_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/forks',
#    'keys_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/teams',
#    'hooks_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/hooks',
#    'issue_events_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/events',
#    'assignees_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/tags',
#    'blobs_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/languages',
#    'stargazers_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/stargazers',
#    'contributors_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/contributors',
#    'subscribers_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/subscribers',
#    'subscription_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/subscription',
#    'commits_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/merges',
#    'archive_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/downloads',
#    'issues_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/wojsamjan/data-engineering-zoomcamp/deployments',
#    'created_at': '2025-04-12T21:26:23Z',
#    'updated_at': '2025-04-12T21:26:23Z',
#    'pushed_at': '2025-04-01T15:40:56Z',
#    'git_url': 'git://github.com/wojsamjan/data-engineering-zoomcamp.git',
#    'ssh_url': 'git@github.com:wojsamjan/data-engineering-zoomcamp.git',
#    'clone_url': 'https://github.com/wojsamjan/data-engineering-zoomcamp.git',
#    'svn_url': 'https://github.com/wojsamjan/data-engineering-zoomcamp',
#    'homepage': '',
#    'size': 8731,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': None,
#    'has_issues': False,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'main',
#    'public': True}},
#  'public': True,
#  'created_at': '2025-04-12T21:26:24Z',
#  'org': {'id': 72699292,
#   'login': 'DataTalksClub',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/orgs/DataTalksClub',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/72699292?'}}

# %%
def process_event(event):
  result = {}

  result['id'] = event['id']
  result['login'] = event['actor']['login']
  result['description'] = event['payload'].get('description')
  timestamp = datetime.fromisoformat(event['created_at'])
  result['timestamp'] = timestamp.timestamp()
  result['created_at'] = event['created_at']

  return result

# %%
#usage
processed_events = []

for event in event_page:
  processed_event = process_event(event)
  processed_events.append(processed_event)

processed_events
# Out:
# [{'id': '48618902835',
#   'login': 'wojsamjan',
#   'description': None,
#   'timestamp': 1744493184.0,
#   'created_at': '2025-04-12T21:26:24Z'},
#  {'id': '48618110953',
#   'login': 'jrgealexq',
#   'description': None,
#   'timestamp': 1744488099.0,
#   'created_at': '2025-04-12T20:01:39Z'},
#  {'id': '48617168749',
#   'login': 'ovidiu-eremia',
#   'description': None,
#   'timestamp': 1744482585.0,
#   'created_at': '2025-04-12T18:29:45Z'},
#  {'id': '48617151331',
#   'login': 'ggledis',
#   'description': None,
#   'timestamp': 1744482485.0,
#   'created_at': '2025-04-12T18:28:05Z'},
#  {'id': '48617150361',
#   'login': 'ggledis',
#   'description': None,
#   'timestamp': 1744482479.0,
#   'created_at': '2025-04-12T18:27:59Z'},
#  {'id': '48616893745',
#   'login': 'adaydan',
#   'description': None,
#   'timestamp': 1744481096.0,
#   'created_at': '2025-04-12T18:04:56Z'},
#  {'id': '48616840596',
#   'login': 'akhileshcs005',
#   'description': None,
#   'timestamp': 1744480831.0,
#   'created_at': '2025-04-12T18:00:31Z'},
#  {'id': '48616832264',
#   'login': 'Rohityadav9575',
#   'description': None,
#   'timestamp': 1744480797.0,
#   'created_at': '2025-04-12T17:59:57Z'},
#  {'id': '48615993501',
#   'login': 'dinuvdm',
#   'description': None,
#   'timestamp': 1744476393.0,
#   'created_at': '2025-04-12T16:46:33Z'},
#  {'id': '48615597375',
#   'login': 'renad-lab',
#   'description': None,
#   'timestamp': 1744474192.0,
#   'created_at': '2025-04-12T16:09:52Z'},
#  {'id': '48615497440',
#   'login': 'fabriziofranchitti',
#   'description': None,
#   'timestamp': 1744473664.0,
#   'created_at': '2025-04-12T16:01:04Z'},
#  {'id': '48615147964',
#   'login': 'Massinho91',
#   'description': None,
#   'timestamp': 1744471713.0,
#   'created_at': '2025-04-12T15:28:33Z'},
#  {'id': '48614660649',
#   'login': 'omarkhaled122',
#   'description': None,
#   'timestamp': 1744469147.0,
#   'created_at': '2025-04-12T14:45:47Z'},
#  {'id': '48614602772',
#   'login': 'ajit4518',
#   'description': None,
#   'timestamp': 1744468829.0,
#   'created_at': '2025-04-12T14:40:29Z'},
#  {'id': '48614453493',
#   'login': 'sochikenny',
#   'description': None,
#   'timestamp': 1744468029.0,
#   'created_at': '2025-04-12T14:27:09Z'},
#  {'id': '48614181838',
#   'login': 'pala2003',
#   'description': None,
#   'timestamp': 1744466667.0,
#   'created_at': '2025-04-12T14:04:27Z'},
#  {'id': '48614104272',
#   'login': 'AhmedDandash',
#   'description': None,
#   'timestamp': 1744466254.0,
#   'created_at': '2025-04-12T13:57:34Z'},
#  {'id': '48614020085',
#   'login': 'pala2003',
#   'description': None,
#   'timestamp': 1744465763.0,
#   'created_at': '2025-04-12T13:49:23Z'},
#  {'id': '48611222324',
#   'login': 'LeMaxV',
#   'description': None,
#   'timestamp': 1744450022.0,
#   'created_at': '2025-04-12T09:27:02Z'},
#  {'id': '48611203144',
#   'login': 'MrRoberST3',
#   'description': None,
#   'timestamp': 1744449909.0,
#   'created_at': '2025-04-12T09:25:09Z'},
#  {'id': '48610418669',
#   'login': 'ulisesaguilar17',
#   'description': None,
#   'timestamp': 1744445329.0,
#   'created_at': '2025-04-12T08:08:49Z'},
#  {'id': '48608922246',
#   'login': 'CoderAtGithub',
#   'description': None,
#   'timestamp': 1744436385.0,
#   'created_at': '2025-04-12T05:39:45Z'},
#  {'id': '48608549581',
#   'login': 'neeraj-a2912',
#   'description': None,
#   'timestamp': 1744434095.0,
#   'created_at': '2025-04-12T05:01:35Z'},
#  {'id': '48608342341',
#   'login': 'Nikhil-Jerome',
#   'description': None,
#   'timestamp': 1744432753.0,
#   'created_at': '2025-04-12T04:39:13Z'},
#  {'id': '48607699200',
#   'login': 'wenwenkong',
#   'description': None,
#   'timestamp': 1744428777.0,
#   'created_at': '2025-04-12T03:32:57Z'},
#  {'id': '48606658043',
#   'login': 'poiu72',
#   'description': None,
#   'timestamp': 1744422631.0,
#   'created_at': '2025-04-12T01:50:31Z'}]

# %%
from datetime import datetime

def process_event(event):
  result = {}

  result['id'] = event['id']
  result['login'] = event['actor']['login']
  result['description'] = event.get('actor', {}).get('payload', {}).get('description')
  result['created_at'] = datetime.strptime(event['created_at'], '%Y-%m-%dT%H:%M:%SZ')
  timestamp = datetime.fromisoformat(event['created_at'])
  result['timestamp'] = timestamp.timestamp()

  return result

process_event(event)
# Out:
# {'id': '48606658043',
#  'login': 'poiu72',
#  'description': None,
#  'created_at': datetime.datetime(2025, 4, 12, 1, 50, 31),
#  'timestamp': 1744422631.0}

# %% [markdown]
# Loading

# %%
#DataBase
import duckdb

conn = duckdb.connect('events_storage')

# %%
processed_events[0]
# Out:
# {'id': '48618902835',
#  'login': 'wojsamjan',
#  'description': None,
#  'timestamp': 1744493184.0,
#  'created_at': '2025-04-12T21:26:24Z'}

# %%
#create a table
conn.execute("""
  CREATE TABLE IF NOT EXISTS events (
    login TEXT PRIMARY KEY,
    description TEXT,
    timestamp DOUBLE,
    createdat STRING
  )
""")

#id TEXT PRIMARY KEY,

# %%
flattened_events = [
    (
      #event['id'],
      event['login'],
      event['description'],
      event['timestamp'],
      event['created_at']
      #datetime.strptime(event['created_at'], '%Y-%m-%dT%H:%M:%SZ').timestamp(),
      #datetime.strptime(event['created_at'], '%Y-%m-%dT%H:%M:%SZ')
    )
    for event in processed_events
]

conn.executemany("""
  INSERT INTO events (login, description, timestamp, createdat)
  VALUES (?, ?, ?, ?)
""", flattened_events)

# %%
df = conn.execute("SELECT * FROM events").fetchdf()
df.head()
# Out:
#      id          login description     timestamp           createdat
# 0  <NA>      wojsamjan        None  1.744493e+09 2025-04-12 21:26:24
# 1  <NA>      jrgealexq        None  1.744488e+09 2025-04-12 20:01:39
# 2  <NA>  ovidiu-eremia        None  1.744483e+09 2025-04-12 18:29:45
# 3  <NA>        ggledis        None  1.744482e+09 2025-04-12 18:28:05
# 4  <NA>        ggledis        None  1.744482e+09 2025-04-12 18:27:59

# %%
conn.close()
